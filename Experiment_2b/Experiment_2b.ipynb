# %%
import pandas as pd
import numpy as np

# Generate a synthetic dataset using random functions
num_rows = 100
data = {
    'existing_column': np.random.randint(1, 100, num_rows),
    'another_column': np.random.randint(50, 150, num_rows),
    'category_column': np.random.choice(['A', 'B', 'C', 'D'], num_rows),
    'numeric_column': np.random.rand(num_rows) * 100,
    'column1': np.random.randint(100, 200, num_rows),
    'column2': np.random.rand(num_rows) * 50
}
df = pd.DataFrame(data)

# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())
# Check data types and general info
df.info()
# Summary statistics
print("Summary statistics:\n", df.describe())
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)
# Create a new column
df['new_column'] = df['existing_column'] * 2
# Create a Series and perform operations
series = df['existing_column']
print("Series addition:", series + 10)
# Filter rows based on conditions
filtered_df = df[(df['existing_column'] > 50) & (df['another_column'] < 100)]
print("Filtered DataFrame:\n", filtered_df)
# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean()
print("Grouped mean:\n", grouped)
# Sorting
df_sorted = df.sort_values(by='numeric_column', ascending=False)
print("Sorted DataFrame:\n", df_sorted)
# Boolean masking
masked_df = df[df['numeric_column'] > df['numeric_column'].median()]

print("Masked DataFrame:\n", masked_df)
# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Create a new DataFrame with selected columns
subset_df = df[['column1', 'column2']]
# Compute summary statistics
print("Total sum:", df['numeric_column'].sum())
print("Mean:", df['numeric_column'].mean())
print("Standard Deviation:", df['numeric_column'].std())
# Out:
# First 5 rows:
#     existing_column  another_column category_column  numeric_column  column1  \
# 0               83              68               D       11.438903      123
# 1               45              90               D       46.721800      184
# 2               52              89               D        5.409335      122
# 3               10              84               B       21.893588      124
# 4               92             147               C       22.861133      126
#
#      column2
# 0  28.119594
# 1  17.617658
# 2  26.223635
# 3  16.826474
# 4  10.807431
# Last 5 rows:
#      existing_column  another_column category_column  numeric_column  column1  \
# 95                8             121               C       53.514394      172
# 96               10             133               B       13.294619      110
# 97               64             113               B       45.371503      104
# 98                8             147               A       30.199536      160
# 99               90             139               D       65.215443      119
#
#       column2
# 95   1.573517
# 96  31.214264
# 97   5.213050
# 98   7.247759
# 99  23.281829
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   existing_column  100 non-null    int64
#  1   another_column   100 non-null    int64
#  2   category_column  100 non-null    object
#  3   numeric_column   100 non-null    float64
#  4   column1          100 non-null    int64
#  5   column2          100 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 4.8+ KB
# Summary statistics:
#         existing_column  another_column  numeric_column     column1     column2
# count       100.000000      100.000000      100.000000  100.000000  100.000000
# mean         47.650000       99.250000       48.134823  151.260000   25.301059
# std          29.688747       30.595892       26.600448   29.063713   14.327413
# min           1.000000       50.000000        2.301610  100.000000    0.250071
# 25%          19.750000       74.750000       24.623740  126.000000   13.536121
# 50%          47.000000       97.000000       47.920937  154.000000   27.455839
# 75%          75.250000      126.250000       65.281490  176.250000   36.855580
# max          97.000000      149.000000       98.709252  199.000000   49.518964
# Series addition: 0      93
# 1      55
# 2      62
# 3      20
# 4     102
#      ...
# 95     18
# 96     20
# 97     74
# 98     18
# 99    100
# Name: existing_column, Length: 100, dtype: int64
# Filtered DataFrame:
#      existing_column  another_column category_column  numeric_column  column1  \
# 0                83              68               D       11.438903      123
# 2                52              89               D        5.409335      122
# 10               63              70               C       69.232855      107
# 16               85              58               D       56.098487      190
# 25               90              59               D       43.199487      181
# 29               81              78               C       63.492705      126
# 31               58              64               A        5.972344      127
# 33               58              81               D       61.771799      189
# 35               92              55               C       46.964985      199
# 36               84              81               B       95.484772      176
# 37               55              63               C       51.588732      106
# 38               92              64               D       12.789911      107
# 41               89              53               A       34.237407      169
# 43               78              52               C       18.391567      170
# 47               60              99               A       93.069257      119
# 49               77              89               B       96.883257      164
# 52               75              76               C       29.317224      150
# 59               57              54               B       43.068068      174
# 62               94              56               D       30.709185      193
# 75               91              60               D       27.644437      169
# 80               58              59               D        7.659476      187
# 82               61              63               B       83.802079      135
# 89               60              51               D       12.435761      162
#
#       column2  new_column
# 0   28.119594         166
# 2   26.223635         104
# 10   0.250071         126
# 16  40.293044         170
# 25  44.550044         180
# 29  37.686837         162
# 31   8.527570         116
# 33  10.966658         116
# 35  14.080988         184
# 36  23.437700         168
# 37  35.426174         110
# 38  35.367962         184
# 41   1.098524         178
# 43  36.755489         156
# 47  18.231059         120
# 49  31.102545         154
# 52  16.235704         150
# 59  31.746603         114
# 62   7.116608         188
# 75  18.092423         182
# 80  38.295546         116
# 82  47.177837         122
# 89  35.918994         120
# Grouped mean:
#  category_column
# A    44.424299
# B    52.871650
# C    45.190720
# D    48.749576
# Name: numeric_column, dtype: float64
# Sorted DataFrame:
#      existing_column  another_column category_column  numeric_column  column1  \
# 65                3              84               D       98.709252      124
# 85               20              85               D       98.033956      172
# 49               77              89               B       96.883257      164
# 92               64             139               B       96.739475      190
# 36               84              81               B       95.484772      176
# ..              ...             ...             ...             ...      ...
# 80               58              59               D        7.659476      187
# 31               58              64               A        5.972344      127
# 2                52              89               D        5.409335      122
# 30                4             101               A        4.698852      145
# 42               25             108               C        2.301610      153
#
#       column2  new_column
# 65  33.035171           6
# 85  16.360825          40
# 49  31.102545         154
# 92  36.750927         128
# 36  23.437700         168
# ..        ...         ...
# 80  38.295546         116
# 31   8.527570         116
# 2   26.223635         104
# 30  49.518964           8
# 42  16.836439          50
#
# [100 rows x 7 columns]
# Masked DataFrame:
#      existing_column  another_column category_column  numeric_column  column1  \
# 7                25              87               D       65.931213      152
# 8                 3              75               D       63.198917      178
# 10               63              70               C       69.232855      107
# 11               80             133               B       55.234469      179
# 12               75             125               D       60.964428      117
# 14               75             137               C       59.265552      100
# 15                6              92               C       53.422895      118
# 16               85              58               D       56.098487      190
# 18               48             114               C       58.907356      118
# 19               21             121               C       82.614189      135
# 20               11              86               B       55.163203      121
# 24                5             115               A       50.653628      131
# 26               21             125               A       79.657183      127
# 27                7              54               A       59.906654      153
# 28                2              62               D       54.191231      168
# 29               81              78               C       63.492705      126
# 32               76             120               A       65.479629      105
# 33               58              81               D       61.771799      189
# 36               84              81               B       95.484772      176
# 37               55              63               C       51.588732      106
# 40               59             149               C       50.019260      129
# 45               14              96               D       87.695426      153
# 47               60              99               A       93.069257      119
# 48               30              74               C       87.620098      155
# 49               77              89               B       96.883257      164
# 51               76             145               B       92.637550      137
# 53               57             127               B       68.027569      186
# 55               10              77               D       89.279455      183
# 56               78             123               B       73.490471      196
# 57               93             126               D       69.617015      101
# 58               44              98               D       69.393748      129
# 60                7              81               D       76.083875      103
# 63               45              79               B       83.475605      129
# 64               45              83               A       57.605300      186
# 65                3              84               D       98.709252      124
# 67               42             138               B       80.256399      108
# 68               93             121               B       62.309244      131
# 71               27              71               B       64.392189      168
# 73               74             129               C       48.876889      131
# 74               96             108               D       57.259017      169
# 76               26             147               D       51.874589      177
# 77               16             110               A       63.930115      184
# 79               66             141               C       84.400425      196
# 82               61              63               B       83.802079      135
# 84               97             146               D       64.442477      193
# 85               20              85               D       98.033956      172
# 88               53             133               C       92.280833      156
# 92               64             139               B       96.739475      190
# 95                8             121               C       53.514394      172
# 99               90             139               D       65.215443      119
#
#       column2  new_column
# 7   30.540297          50
# 8    8.038761           6
# 10   0.250071         126
# 11  40.730722         160
# 12  33.568480         150
# 14  40.996456         150
# 15  14.998452          12
# 16  40.293044         170
# 18  31.269735          96
# 19  25.995491          42
# 20  26.843811          22
# 24  28.378030          10
# 26  13.962481          42
# 27   7.086448          14
# 28  27.365810           4
# 29  37.686837         162
# 32  40.169195         152
# 33  10.966658         116
# 36  23.437700         168
# 37  35.426174         110
# 40  38.438657         118
# 45   3.034363          28
# 47  18.231059         120
# 48  33.082893          60
# 49  31.102545         154
# 51   9.348551         152
# 53  44.769765         114
# 55  23.841979          20
# 56  29.616423         156
# 57  44.429970         186
# 58  27.545869          88
# 60  36.661907          14
# 63  43.598676          90
# 64  21.419675          90
# 65  33.035171           6
# 67  36.250159          84
# 68  46.574910         186
# 71   8.017650          54
# 73   1.039996         148
# 74   2.102335         192
# 76  47.783338          52
# 77  39.892547          32
# 79  47.124789         132
# 82  47.177837         122
# 84  16.855812         194
# 85  16.360825          40
# 88  12.257039         106
# 92  36.750927         128
# 95   1.573517          16
# 99  23.281829         180
# Total sum: 4813.482343196549
# Mean: 48.134823431965486
# Standard Deviation: 26.60044778449761
